# %% [markdown]
# <a href="https://colab.research.google.com/github/ManviGumber08/comp3132/blob/main/Assignment_02_Instructions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 02
# The following assignment is a step-by-step process to implement a multiclass classification using Iris dataset.
#
# **Note:**
#
# - Please note that every question has 0.5 and it provides five out of total ten marks for the assignment. 5/10%
#
# The video presentation 5/10%.
#
# Without YouTube presentation you receive no mark for the submission.

# %%
#00 The iris.csv file (Iris dataset) is located in the Assignment folder below the current ipynb file.

# %% [markdown]
#  **Important Note:** We are NOT allowed to import the dataset from Keras. We need to upload the provided iris.csv file to colab from our Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/
# Out:
#  assign1_Manvi.ipynb		       iris.csv         Untitled	  Untitled1.ipynb
# 'Assignment 02 - Instructions.ipynb'   LabWeek3.ipynb   Untitled0.ipynb  'Untitled (2)'
#  Assignment2			       LabWeek6.ipynb  'Untitled (1)'	  Untitled2.ipynb

# %%
import pandas as pd

file_path = "/content/drive/My Drive/Colab Notebooks/iris.csv"
iris = pd.read_csv(file_path)

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#01-a Find the path of iris.csv file, and save it in a variable called fileName.
file_path = "/content/drive/My Drive/Colab Notebooks/iris.csv"

# %%
#01-b Read the content of the iris.csv file and save it in a variable, named iris.
import pandas as pd
iris = pd.read_csv(file_path)

# %%
#01-c Show the first 5 rows of the dataframe.
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# As you see, the last column contains strings. We want to convert these strings to integers,  and we can work with them easily in our Neural Network model.
#
# setosa -> 0
#
# versicolor -> 1
#
# virginica -> 2

# %%
#2-a Convert the last column strings to integers, as
# setosa -> 0
# versicolor -> 1
# virginica -> 2
label_mapping = {"setosa": 0, "versicolor": 1, "virginica": 2}
iris["species"] = iris["species"].map(label_mapping)

# %%
#2-b Now, check the first 5 elements of the iris dataset once again:
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#03-a Select the first four columns of the dataframe as the Data and call the data x.

# %%
X = iris.iloc[:, :-1]  # Select all rows, but only the first four columns
print(X.head())  # Display the first 5 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#03-b Select the last column as the label and call it y.

# %%
y = iris.iloc[:, -1]  # Select all rows, but only the last column
print(y.head())  # Display the first 5 labels
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
#04 Now, it is the time to split the data (x) and the label (y) into training and testin segments,
#   and call them parts x_train,x_test,y_train,y_test.

# %%
#04-a Split the data, and label ito training and testing segments, while the size of test data is 20%,
#     and use randome_state = 123 to make all the answers similar in the whole class.

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting the data: 80% for training, 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
#04-b Check the first five rows of  x_train,x_test,y_train,y_test.

# %%
print("X_train (first 5 rows):\n", X_train.head())
print("X_test (first 5 rows):\n", X_test.head())
print("y_train (first 5 rows):\n", y_train.head())
print("y_test (first 5 rows):\n", y_test.head())
# Out:
# X_train (first 5 rows):
#       sepal_length  sepal_width  petal_length  petal_width
# 130           7.4          2.8           6.1          1.9
# 119           6.0          2.2           5.0          1.5
# 29            4.7          3.2           1.6          0.2
# 0             5.1          3.5           1.4          0.2
# 62            6.0          2.2           4.0          1.0
# X_test (first 5 rows):
#       sepal_length  sepal_width  petal_length  petal_width
# 72            6.3          2.5           4.9          1.5
# 112           6.8          3.0           5.5          2.1
# 132           6.4          2.8           5.6          2.2
# 88            5.6          3.0           4.1          1.3
# 37            4.9          3.1           1.5          0.1
# y_train (first 5 rows):
#  130    2
# 119    2
# 29     0
# 0      0
# 62     1
# Name: species, dtype: int64
# y_test (first 5 rows):
#  72     1
# 112    2
# 132    2
# 88     1
# 37     0
# Name: species, dtype: int64

# %%
#04-c Check the length of the x_train and x_test. If the numbers are 120 & 30, AWESOME!
#     You are good to continue!

# %%
print("Length of X_train:", len(X_train))
print("Length of X_test:", len(X_test))
# Out:
# Length of X_train: 120
# Length of X_test: 30

# %%
#05-a Convert y_train and y_test from categorical to one-hot encoded values, and call them
#     one_hot_train_labels, and one_hot_test_labels, respectively.

# %%
from tensorflow.keras.utils import to_categorical

# %%
# Convert categorical labels to one-hot encoding
one_hot_train_labels = to_categorical(y_train, num_classes=3)
one_hot_test_labels = to_categorical(y_test, num_classes=3)

# %%
print("Original y_train values:\n", y_train[:5].values)
print("\nOne-Hot Encoded y_train:\n", one_hot_train_labels[:5])
# Out:
# Original y_train values:
#  [2 2 0 0 1]
#
# One-Hot Encoded y_train:
#  [[0. 0. 1.]
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]]

# %%
#06-a Define a sequential model that contains 3 dense layers.
#     In the first and second layers, use 100 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3 as the number of output,
#     and the reason is we have three classes (setosa -> 0, versicolor -> 1, virginica -> 2)
#     Also, please pick an appropriate loss function for the last layer.
#     (You may already have guessed what could be the best loss function when we have converted the categorical values to encoded values.)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Define a Sequential model
model = Sequential([
    Dense(100, activation='relu', input_shape=(4,)),  # First hidden layer with 100 neurons
    Dense(100, activation='relu'),  # Second hidden layer with 100 neurons
    Dense(3, activation='softmax')  # Output layer with 3 neurons (softmax for multi-class classification)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
loss_function = 'categorical_crossentropy'

# %%
# Compile the model
model.compile(
    optimizer='rmsprop',  # RMSprop optimizer
    loss=loss_function,   # Categorical crossentropy for multi-class classification
    metrics=['accuracy']  # Track accuracy during training
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │             500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             303 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,903 (42.59 KB)
#  Trainable params: 10,903 (42.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#07-a Train your model using epoch=20, batch=10.

# %%
history = model.fit(
    X_train, one_hot_train_labels,  # Training data
    epochs=20,                      # Number of epochs
    batch_size=10,                   # Batch size
    validation_data=(X_test, one_hot_test_labels)  # Validation data
)
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9799 - loss: 0.0806 - val_accuracy: 0.8667 - val_loss: 0.1368
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9722 - loss: 0.0797 - val_accuracy: 0.9667 - val_loss: 0.1193
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0524 - val_accuracy: 0.9000 - val_loss: 0.1174
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9814 - loss: 0.0754 - val_accuracy: 0.9000 - val_loss: 0.1740
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9455 - loss: 0.1353 - val_accuracy: 0.8667 - val_loss: 0.1344
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9522 - loss: 0.0942 - val_accuracy: 0.9667 - val_loss: 0.1046
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9801 - loss: 0.0877 - val_accuracy: 0.9667 - val_loss: 0.1065
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9909 - loss: 0.0640 - val_accuracy: 0.9667 - val_loss: 0.1014
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9799 - loss: 0.0473 - val_accuracy: 0.8667 - val_loss: 0.2540
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9594 - loss: 0.1013 - val_accuracy: 0.9000 - val_loss: 0.1605
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9499 - loss: 0.1036 - val_accuracy: 0.9667 - val_loss: 0.1010
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9616 - loss: 0.0676 - val_accuracy: 0.9667 - val_loss: 0.1070
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9442 - loss: 0.1091 - val_accuracy: 0.9000 - val_loss: 0.1227
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9849 - loss: 0.0490 - val_accuracy: 0.8667 - val_loss: 0.2863
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9623 - loss: 0.0716 - val_accuracy: 0.9667 - val_loss: 0.0994
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9846 - loss: 0.0671 - val_accuracy: 0.9667 - val_loss: 0.1007
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.0364 - val_accuracy: 0.9000 - val_loss: 0.1958
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9711 - loss: 0.0618 - val_accuracy: 0.9667 - val_loss: 0.1043
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.0690 - val_accuracy: 0.9667 - val_loss: 0.1085
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9735 - loss: 0.0700 - val_accuracy: 0.9667 - val_loss: 0.0949

# %%
print(X_train.shape)  # Should print (120, 4)
print(one_hot_train_labels.shape)  # Should print (120, 3)
# Out:
# (120, 4)
# (120, 3)

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
#08-a Calculate the result, evaluating x_test and one_hot_test_label, and report on the accuracy of your model.

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, one_hot_test_labels)

# Print the accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9667 - loss: 0.0949
# Test Accuracy: 96.67%

# %%
print(X_test.shape)  # Should print (30, 4)
print(one_hot_test_labels.shape)  # Should print (30, 3)
# Out:
# (30, 4)
# (30, 3)

# %%
history = model.fit(X_train, one_hot_train_labels, epochs=50, batch_size=5, validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9806 - loss: 0.0535 - val_accuracy: 0.8667 - val_loss: 0.2343
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9368 - loss: 0.1034 - val_accuracy: 0.9667 - val_loss: 0.0981
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9127 - loss: 0.1970 - val_accuracy: 0.9000 - val_loss: 0.1208
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9846 - loss: 0.0586 - val_accuracy: 0.8667 - val_loss: 0.2888
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9304 - loss: 0.1231 - val_accuracy: 0.9667 - val_loss: 0.1007
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9749 - loss: 0.0808 - val_accuracy: 0.9667 - val_loss: 0.0962
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0906 - val_accuracy: 0.9000 - val_loss: 0.1413
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9750 - loss: 0.0657 - val_accuracy: 0.8667 - val_loss: 0.2484
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9472 - loss: 0.1134 - val_accuracy: 0.9667 - val_loss: 0.1033
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9819 - loss: 0.0398 - val_accuracy: 0.9667 - val_loss: 0.0915
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0258 - val_accuracy: 0.9000 - val_loss: 0.1737
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9809 - loss: 0.0772 - val_accuracy: 0.9667 - val_loss: 0.0917
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9693 - loss: 0.1197 - val_accuracy: 0.9000 - val_loss: 0.1126
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9472 - loss: 0.1246 - val_accuracy: 0.9667 - val_loss: 0.1005
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9785 - loss: 0.0568 - val_accuracy: 0.9667 - val_loss: 0.0908
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.9667 - val_loss: 0.0950
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9539 - loss: 0.1137 - val_accuracy: 0.9667 - val_loss: 0.1337
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9814 - loss: 0.0919 - val_accuracy: 0.9667 - val_loss: 0.1083
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9570 - loss: 0.0763 - val_accuracy: 0.9000 - val_loss: 0.1274
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9662 - loss: 0.1325 - val_accuracy: 0.9667 - val_loss: 0.0886
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 0.0657 - val_accuracy: 0.9667 - val_loss: 0.0938
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9321 - loss: 0.1466 - val_accuracy: 0.9333 - val_loss: 0.2047
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9516 - loss: 0.0956 - val_accuracy: 0.9667 - val_loss: 0.1056
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.1001 - val_accuracy: 0.9000 - val_loss: 0.1422
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9797 - loss: 0.0352 - val_accuracy: 0.9000 - val_loss: 0.1113
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9877 - loss: 0.0612 - val_accuracy: 0.9667 - val_loss: 0.1026
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9628 - loss: 0.1125 - val_accuracy: 0.9667 - val_loss: 0.0890
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9525 - loss: 0.0819 - val_accuracy: 0.9667 - val_loss: 0.1114
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9635 - loss: 0.0732 - val_accuracy: 0.9667 - val_loss: 0.0857
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9578 - loss: 0.1240 - val_accuracy: 0.9667 - val_loss: 0.0901
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9946 - loss: 0.0336 - val_accuracy: 0.9000 - val_loss: 0.1206
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9915 - loss: 0.0404 - val_accuracy: 0.9667 - val_loss: 0.0861
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9930 - loss: 0.0406 - val_accuracy: 0.9667 - val_loss: 0.0915
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9753 - loss: 0.0533 - val_accuracy: 0.9667 - val_loss: 0.0891
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0588 - val_accuracy: 0.9000 - val_loss: 0.1549
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0383 - val_accuracy: 0.9667 - val_loss: 0.1047
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9568 - loss: 0.0958 - val_accuracy: 0.9667 - val_loss: 0.0868
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 0.0580 - val_accuracy: 0.9333 - val_loss: 0.0981
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9769 - loss: 0.0625 - val_accuracy: 0.9000 - val_loss: 0.1143
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9788 - loss: 0.0581 - val_accuracy: 0.9000 - val_loss: 0.1283
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9326 - loss: 0.1390 - val_accuracy: 0.9667 - val_loss: 0.0890
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9624 - loss: 0.1013 - val_accuracy: 0.9000 - val_loss: 0.2021
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.0996 - val_accuracy: 0.9667 - val_loss: 0.0862
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9480 - loss: 0.0965 - val_accuracy: 0.9667 - val_loss: 0.0979
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9414 - loss: 0.1026 - val_accuracy: 0.9667 - val_loss: 0.0833
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9717 - loss: 0.1125 - val_accuracy: 0.9667 - val_loss: 0.0846
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9872 - loss: 0.0657 - val_accuracy: 0.9667 - val_loss: 0.0905
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9798 - loss: 0.0757 - val_accuracy: 0.9667 - val_loss: 0.0964
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.1014 - val_accuracy: 0.9000 - val_loss: 0.2021
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9496 - loss: 0.0819 - val_accuracy: 0.9000 - val_loss: 0.1253

# %%
import numpy as np

# Get predictions for X_test
predictions = model.predict(X_test)

# Convert predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(one_hot_test_labels, axis=1)

# Compare true labels with predictions
print("Predicted:", predicted_labels)
print("Actual:   ", true_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Predicted: [1 2 2 1 0 1 1 0 0 1 2 0 1 2 2 2 0 0 1 0 0 1 0 1 0 0 0 2 2 0]
# Actual:    [1 2 2 1 0 2 1 0 0 1 2 0 1 2 2 2 0 0 1 0 0 2 0 2 0 0 0 2 2 0]

# %%
#09-a Now, we repeat all we have done in #06-a with the following parameters:
#     In the first and second hidden layers, use 10 hidden units (neurons) and a 'relu' activation function.
#     For the output layer, we need to use 3.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Define the new model
model2 = keras.Sequential([
    layers.Dense(10, activation="relu", input_shape=(4,)),  # First hidden layer (10 neurons)
    layers.Dense(10, activation="relu"),  # Second hidden layer (10 neurons)
    layers.Dense(3, activation="softmax")  # Output layer (3 neurons for 3 classes)
])

# Compile the model
model2.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# Summary of the new model
model2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 10)                  │              50 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10)                  │             110 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 3)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history2 = model2.fit(X_train, one_hot_train_labels,
                      epochs=20,
                      batch_size=10,
                      validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.3511 - loss: 1.6768 - val_accuracy: 0.7333 - val_loss: 0.9178
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6375 - loss: 1.2225 - val_accuracy: 0.8000 - val_loss: 0.7933
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6706 - loss: 0.9473 - val_accuracy: 0.8000 - val_loss: 0.7224
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6053 - loss: 0.8779 - val_accuracy: 0.8000 - val_loss: 0.6886
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6040 - loss: 0.8050 - val_accuracy: 0.7667 - val_loss: 0.6714
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6171 - loss: 0.7281 - val_accuracy: 0.6667 - val_loss: 0.6543
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5854 - loss: 0.6943 - val_accuracy: 0.6000 - val_loss: 0.6338
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5809 - loss: 0.6951 - val_accuracy: 0.6333 - val_loss: 0.6019
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6795 - loss: 0.6581 - val_accuracy: 0.6667 - val_loss: 0.5692
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6749 - loss: 0.6553 - val_accuracy: 0.7000 - val_loss: 0.5369
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7032 - loss: 0.6403 - val_accuracy: 0.8333 - val_loss: 0.5118
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8605 - loss: 0.5847 - val_accuracy: 0.7333 - val_loss: 0.5032
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7666 - loss: 0.5475 - val_accuracy: 0.8333 - val_loss: 0.4809
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8970 - loss: 0.5623 - val_accuracy: 0.7667 - val_loss: 0.4671
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8309 - loss: 0.5552 - val_accuracy: 0.8333 - val_loss: 0.4546
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8606 - loss: 0.5285 - val_accuracy: 0.8667 - val_loss: 0.4414
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9320 - loss: 0.4845 - val_accuracy: 0.8667 - val_loss: 0.4326
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9215 - loss: 0.4820 - val_accuracy: 0.8667 - val_loss: 0.4176
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9165 - loss: 0.4886 - val_accuracy: 0.8667 - val_loss: 0.4057
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9151 - loss: 0.4638 - val_accuracy: 0.8667 - val_loss: 0.4036

# %%
test_loss2, test_accuracy2 = model2.evaluate(X_test, one_hot_test_labels)
print(f"Test Accuracy (New Model): {test_accuracy2 * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8667 - loss: 0.4036
# Test Accuracy (New Model): 86.67%

# %%
print(f"Test Accuracy (Old Model - 100 Neurons): {test_accuracy * 100:.2f}%")
print(f"Test Accuracy (New Model - 10 Neurons): {test_accuracy2 * 100:.2f}%")
# Out:
# Test Accuracy (Old Model - 100 Neurons): 96.67%
# Test Accuracy (New Model - 10 Neurons): 86.67%

# %%
#09-b Use the same settings as for #06-b (compile using the same optimizer, loss function) and output the accuracy

# %%
# Compile the model with same settings
model2.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history2 = model2.fit(X_train, one_hot_train_labels,
                      epochs=4,
                      batch_size=10,
                      validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8895 - loss: 0.4836 - val_accuracy: 0.9333 - val_loss: 0.3785
# Epoch 2/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9492 - loss: 0.4152 - val_accuracy: 0.9000 - val_loss: 0.3770
# Epoch 3/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8917 - loss: 0.4673 - val_accuracy: 0.9333 - val_loss: 0.3507
# Epoch 4/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9583 - loss: 0.4379 - val_accuracy: 0.9333 - val_loss: 0.3436

# %%
# Evaluate the new model
test_loss2, test_accuracy2 = model2.evaluate(X_test, one_hot_test_labels)

# Print the accuracy
print(f"Test Accuracy (New Model - 10 Neurons, 4 Epochs): {test_accuracy2 * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9333 - loss: 0.3436
# Test Accuracy (New Model - 10 Neurons, 4 Epochs): 93.33%

# %%
#09-c Please fit your model using epoch=4, batch=10.

# %%
history3 = model2.fit(X_train, one_hot_train_labels,
                      epochs=4,
                      batch_size=10,
                      validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9268 - loss: 0.4019 - val_accuracy: 0.9333 - val_loss: 0.3347
# Epoch 2/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9585 - loss: 0.3702 - val_accuracy: 0.9333 - val_loss: 0.3312
# Epoch 3/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9804 - loss: 0.3786 - val_accuracy: 0.9667 - val_loss: 0.3274
# Epoch 4/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9681 - loss: 0.3764 - val_accuracy: 0.9667 - val_loss: 0.3240

# %%
#09-d Calculate the result, evaluating x_test and one_hot_test_label, and report on the accuracy of your model.

# %%
loss, accuracy = model2.evaluate(X_test, one_hot_test_labels)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9667 - loss: 0.3240
# Test Loss: 0.3240
# Test Accuracy: 0.9667

# %%
#10-a In your video submission, explain each line of your code, and the arguments you've used
# Ensure to answer the following questions at a minimum:
# 10-a-i) How the number of layers or hidden units could impact the accuracy of our model.
# 10-a-ii) Do we always suffer from overfitting?
# 10-a-iii) How can we detect overfitting?
# 10-a-iv) How can we reduce overfitting?

# %%
#10-b
# Use different settings than the ones we chose in #09
# Change each of the following once:
#   i)   optimizer
#   ii)  number of layers
#   iii) hidden units
#   iv)  number of epochs
#   v)   batch_size
# Change one parameter at a time, and rerun the cell(s), then explain the output

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(4,)),
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),  # Extra hidden layer added
    Dense(3, activation='softmax')
])

# %%
model = Sequential([
    Dense(50, activation='relu', input_shape=(4,)),
    Dense(50, activation='relu'),
    Dense(3, activation='softmax')
])

# %%
# Compile the model before training
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, one_hot_train_labels,
                    epochs=10, batch_size=10,
                    validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4693 - loss: 1.2051 - val_accuracy: 0.6333 - val_loss: 0.9327
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7757 - loss: 0.8536 - val_accuracy: 0.8667 - val_loss: 0.6812
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7920 - loss: 0.6967 - val_accuracy: 0.8667 - val_loss: 0.5979
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8762 - loss: 0.6300 - val_accuracy: 0.9667 - val_loss: 0.5155
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9503 - loss: 0.5543 - val_accuracy: 0.9667 - val_loss: 0.4532
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9493 - loss: 0.5000 - val_accuracy: 0.9667 - val_loss: 0.4106
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9786 - loss: 0.4336 - val_accuracy: 0.9667 - val_loss: 0.3732
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9768 - loss: 0.3838 - val_accuracy: 0.9667 - val_loss: 0.3527
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9876 - loss: 0.3722 - val_accuracy: 1.0000 - val_loss: 0.3307
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9521 - loss: 0.3550 - val_accuracy: 0.9667 - val_loss: 0.2993

# %%
history = model.fit(X_train, one_hot_train_labels, epochs=4, batch_size=32, validation_data=(X_test, one_hot_test_labels))
# Out:
# Epoch 1/4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9690 - loss: 0.3116 - val_accuracy: 0.9667 - val_loss: 0.3105
# Epoch 2/4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9437 - loss: 0.3190 - val_accuracy: 0.9667 - val_loss: 0.3040
# Epoch 3/4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9708 - loss: 0.2909 - val_accuracy: 0.9667 - val_loss: 0.2803
# Epoch 4/4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9556 - loss: 0.3124 - val_accuracy: 1.0000 - val_loss: 0.2792

# %% [markdown]
# ---
# # Deliverables:
# 1. Submit the current ipynb file on D2L
# 2. Please record and upload to YouTube 3-6 minute recorded video clip (aim for 5 minutes) describing the answers to the questions above, espcially #10.
#
# Notes:
# - In your submission, YOU MUST SUBMIT A LINK TO YOUR YOUTUBE VIDEO as a TEXT SUBMISSION SECTION on your D2L submission.
# - Omitting this D2L comment will result in a 0% for your total mark.
